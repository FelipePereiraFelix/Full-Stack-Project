# %% [markdown]
# # Aula 1: Interface do Aplicativo
#
# Necessário baixar Aplicativos: **Node.js** e **VSCode**.
#
# ## Primeiramente iremos abrir o Terminal
#
# Baixaremos o pacote do **React**
#
# npm = node packet manager
#
# Uitilizaremos o **Vite** para fazer o processo de Build, para facilitar os código.
#
# Para utilizar o Vite: no terminal daremos um
#
# ```powershell
#
# cd "./Aula 1/Gabarito da Aula 1"
#
# de enter
#
# depois:
#
# npm create vitelatest .
# need to install following packages:
# create-vitte@6.2.0
# Ok to procced?
#
# Aqui coloque "Y" ou "S"
#
# Dps que confirmar escolha a linguagem
#
# No caso da linguagem utilizaremos o "React" e o "Javascript"
#
# Vai aparecer o "npm install" e o "npm run dev"
# ```
#
# Com isso ele vai olhar onde você está
#
# O que é um .json, é Javascript Object Notation.
#
# Ele ainda não está com arquivos que você precisa, então dar "npm install" vai baixar todas depedências que você precisa.
#
# Ele vai criar a pasta: node_modules.
#
# npm run dev: No próprio package.json tem o json, e vai procurar o que você quer rodar dentro do package.json, seria como algo para poupar código.
#
# Depoi de um npm run dev.
#
# Ele vai abrir o Vite+React na tela. E um contador na tela, para você testar e ta funcionando.
#
# ### Depois de tudo isso se inicia o projeto pra valer
#
# Aperte ctrl+k e ctrl+o, feche o outro projeto, e abra um novo.
#
# Delete o vite.png, delete o App.css, delete o que tiver de baixo do **return** para baixo do App.jsx. Delete apenas a escrita dentro do index.css. Delete também o **Readme.rd**
#
# Nosso arquivo principal, é o **main.jsx**
#
# Começaremos no inde.html.
#
# O que tem no html de importante:
#
# ```html
#
# <!-- Cabeça do html -->
# <head>
# <!-- Corpo do html -->
# <body>
#     <div id="root"></div>
#
#     <script type="module" src="/src/main.jsx"></script>
#
# ```
#
# Não faz sentido usar react se não vai usar componente.
#
# Depois que formos para o **main.jsx** teremos os imports, e o que ta puxando da onde.
#
# dps temos o :
#
# ```jsx
#
# createRoot(document.getElementIByd("root")).render(
#     <ScrictMode>
#     <App />
#     </StrictMode>
# );
#
# ```
#
# O jsx é um javascript com sintaxe de Html
#
# Todo componente é uma função, que vai nos retornar algo.
#
# dentro do return vamos colocar o <h1></h1>, dentro do jsx.
#
# O App.jsx ta assim:
#
# ```jsx
# function App() {
#     return <h1>Olá, Mundo!</h1>;
# }
#
# export default App;
# ```
#
# Dentro do jsx pode também ser colocado console.log("Olá, Mundo!");
#
# dentro do **main.jsx** vamos botar um
#
# ```jsx
# import App from "./App.jsx";
#
# ```
#
# Aqui estamos criando um componente, e depois importando ele para utilizar.
#
# Nós copiaremos a pasta "assets" para onde iremos estar criando o projeto.
#
# Depois alteraremos o ícone do **Vite** para o **Spotify**.
#
# Iremos por uma //Arrow Function no App.jsx.
#
# ```jsx
# // Arrow Function
# // const = Variável
# const  App2 = () => {
#     console.log("Olá, Mundo!");
#
#     return <h1>Olá, Mundo!</h1>;
# }
#
# export default App;
#
# ```
#
# Vamos criar o **App2.jsx**
#
# ```jsx
# // React Arrow Function
# rafce // Ele já cria uma base de Arrow Function direto.
# //Arrow Function
# const App2 = () => <h1>Olá, Mundo!</h1>;
#
# ```
#
# da um ctrl+c para parar o servidor no terminal.
#
# ### Agora partiremos do zero: New folder: Gabarito da Aula 1
#
# no terminal:
#
#
# ```powershell
#
# npm create vitelatest .
#
# React -> Enter
#
# npm i
#
# npm run dev
#
# ```
#
# delete as informações dentro do "return" mas não o return.
#
# React: Da alt tab, e fica vendo o que ta acontecendo, até há formas de debugar, mas é muito bom ficar dando alt+tab.
#
# Vamos apagar o App.css, vite.svg, deletar o count no App.jsx, tira os imports, tira o index.css, deleta o public, deleta o Readme.md.
#
# Cria um New File> App2.jsx
#
# Coloque um rafce para começar o React.
#
# New Folder> components > new file > Header.jsx >
#
# dentro do App2.jsx // Nomeação de Componente e //PascalCase
#
# ```jsx
# // Nomeação de Componente
# //PascalCase
#
# // Nomeação de Variável, Função....
# // camelCase
# // A primeira é sempre minúscula
#
# // export default, posso importar com qualquer nome e sem chaves
# // export "sem default", só pode importar entre chaves
#
# // Self closing tag
# // <Header></Header>
# // <Header/>
#
# // Nomeação de classes em CSS
# // Metodologia BEM
# // Blocks
# // Elements
# // Modifiers
# // bloco_elemento--modificador
# // header
# // header__link
# // header__link--small
# //item-list__header
# // Nomes compostos são separados por -
#
# // Tag vazia em React se chama Fragment ou Fragmento
#
# // Componentes recebem "props"
# ```
#
# App.jsx
#
# ```jsx
# return <Header/>;
# ```
#
# Agora queremos uma imagem e uma ancora, botaremos no Header.jsx
#
# ```jsx
# // import spotifylogo
# import logoSpotify from "../assets/logo/spotify-logo.png";
# {
# return<div>
#     <img src={logoSpotify} alt="Logo do Spotify">
#
#     <a className ="header__link">
#     <h1>Spotify</h1>
#     </a>
#
#     </div>
#     );
# }
# ```
#
# Tendo um "root" num site já deixa claro que ele ta usando **React**.
#
# Agora vamos para o index.css
#
# ctrl + . + ,
#
# Inspecione os elementos na página. O próprio navegador já vem com estilos prontos, porém iremos mudar, e em geral cada navegador tem o seu.
#
# Azul é a parte do conteúdo. E o amarelo é o espaçamento.
#
# ```css
# /* Reset */
# * {
#     margin: 0;
#     padding:0;
#     box-sizing: border-box;
# }
#
# body {
#     background-color: black;
#     color: white;
#     font-family: "Montserrat", sans-serif;
# }
#
# a {
#     color:inherit;
#     text-decoration: none;
# }
#
# #root{
#     height:100svh;
#     display:flex;
#     flex-direction:column;
# }
#
# /* Header */
#
# .header {
#     padding:10px 20px;
#     display:flex;
#     justify-content:space-between;
#     align-items:center;
# }
#
# .header__link:hover {
#     text-decoration:underline;
# }
#
# .main{
#     padding:20px;
#     margin: 0 10px 20px;
#     border-radius: 150px;
#     flex:1;
#     background-image:linear-gradient(to bottom, #062d14, black);
# }
#
# .main__texts{
#     display:flex;
#     justify-content:space-between;
#     align-items:center;
#
# }
#
# .main__linl:hover{
#     text-decoration:underline;
# }
# ```
#
# O "*" seleciona todos elementos de uma página.
#
# Todo elemento dentro do html é uma caixa. E essa caixa é representada pela box-model, e ela é composta de vário elementos. O azul é o primeiro, que é o conteúdo. Depois do azul vem o padding, o espaçamento interno.
#
# O que o padding faz: Quando coloca espaçamento interno, ele cria um espaço interno np elemento.
#
# Dependendo da quantidade de elementos, ele coloca conforme os valores.
#
# Primeiro pixels, em cima.
#
# Margin: Espaçamento externo.
#
# Border: É a borda do margin. Até aqui estamos falando do elemento, depois disso pode ou não compor.
#
# width: Largura.
#
# Dentro da Div, iremos usar className, ao invés do class, justamente por ser jsx, e não html.
#
# ```jsx
# <div className="header">
# </div>
# ```
#
# ### display: flex;
#
# Quando fazemos isso, ele virá um flex container. Ele abre também o Flexbox editor.
#
# dentro do components > Main.jsx >
#
# Vamos no Font Awesome Docs, e vou baixar pelo terminal os itens que irei ler.
#
# Busque o circle-play no font-awesome para React, e coloque no Main.jsx.
#
# import para não dar erro:
#
# ```jsx
# import {FontAwesomeIcon} from "@fontawesome/react-fontawesome";
# import {faCirclePlay} from "@fontawseome/..."
# ```
#
#
# ### Minha Conclusão sobre a primeira aula
#
# Fiquei bem enrolado no começo, o Diego acabou falando um pouco rápido demais algumas coisas. Mas o desafio de ensinar React tudo em uma aula para mim é de uma didática fenomenal, o fato de não poder em prática durante as aulas também é algo muito bom, que deixa claro que devemos práticar depois, já tem os conteúdos na mão também, agora é só botar em prática e ver as coisas funcionando ou tentar faze-las funcionar.
#
# Achei mais explicativo que outra aula que tive sobre, e é detalhe por detalhe, cada passo explicado, aprendi muito sobre jsx e css nessa aula, desde conceitos simples, até coisas que eu já havia colocado em projetos mas não sabia verdadeiramente o que fazia.
#
# Nota final: 8,5/10.
#
# Por ter sido rápido demais, e ter muita coisa feita rápida, eu acabei ficando bem perdido, por isso não dei 9.
#
# ### Anotações Bônus, depois de ter botado em prática:
#
# Simplesmente muito bom, super fácil, foi ótimo rever os conceitos e assim que der vou tirar um tempo para fazer as aulas complementares. Mas por agora terminei o projeto básico.
#
#
# ### Anotações Bônus do Bônus
#
# Fiz essa aula de novo, para poder rever os códigos, e fazer as anotações, tive uns problemas e por isso tive que refaze-la. Agora basta apenas terminar a parte prática das outras. Essa com certeza é a mais fácil de todas, então se preparem pelo o que está por vir.

# %% [markdown]
# # Aula 2: Back-End
#
# Sempre que estiver numa pasta nova, coloque o comando "npm i" para a parecer o node modules
#
# Depois o "npm run dev", não de kill no terminal, apenas feche.
#
# ### Hoje apenas puxaremos as informações necessárias
#
# Nós iremos refatorar o código, então deixaremos mais legivel, mais eficiente. Porém fazendo a mesma coisa.
#
# Primeiramente criaremos o nosso primeiro componente: ItemList.jsx. E de um rafce.
#
# Dentro do ItemList.jsx
#
# ```jsx
#
# import ItemList from "./ItemList";
#
# <div className="main">
#      {/*Item List de Artistas*/}
#     <itemList title="Artistas" items=[10]/>
#
#     <ItemList title="Músicas" items=[20]/>
# </div>
#
# // Isso é dentro do Main.jsx
#
# ```
#
# Aqui é a parte que transformamos o ItemList em um componente.
#
# Encontre os single-item dentro do ItemList.jsx que você passou para ele. E crie o SingleItem.jsx, copia um dos componentes.
#
# No ItemList.jsx
#
# ```jsx
# import SingleItem from "./SingleItem";
# const ItemList = (props);
# ```
# Dentro do SingleItem coloque o ícone do Play importando, e passando que o SingleItem vai para o SingleItem.jsx ao invés de manter no ItemList.jsx
#
# Mais anotações no App2.jsx, veja na primeira aula para ver, a parte de (// Props)
#
# Então o props cospe valores do json para o site.
#
# Ele cuspiu mais de uma vez, justamente porque o StrictMode cospe 2 vezes a mesma coisa. Isso serve para evitar problemas durante o desenvolvimento, isso serve para ver a robustez, pq se uma vez deu certo, na segunda pode dar errado. O ideal é não tirar ele.
#
#
# ### Parte Lógica: Javascript
#
# Hoje iremos ir de cabeça em Javascript
#
# Teste feito no inspecionar do Projeto Spotify:
#
# ```javascript
# // Duas formas de puxar o Title e as músicas, aqui é para acessar as informações.
# const obj = {title = "Músicas"}
# obj{"title"}
# ```
#
# Como desestruturar:
#
# ```javascript
# cont{title} = {title = "Música"}
# // Outra forma, de ser mais específico na informação:
# cont{title} = {title = "Música", name: "Amo noite e dia"}
# ```
#
# Quando colocar o Title, ele vai encontrar direitinho o que está procurando, sem problemas. E vai entrar em conceito a desestruturação.
#
# Em default não precisa desestroturar.
#
# Sempre que for escrever html dentro de um jsx, não coloque title populares, mas sim {title} populares.
#
# Para comparações em Javascript o ideal é usar ===, e não ==. Para comparações que fazem sentido, já que queremos saber a propriedade, e não o valor ou escrita.
#
# Iremos construir uma Lógica, para poder colocar as repetições de SingleItem, dentro do ItemList.jsx.
#
# Vamos fazer uma comparação usando if.
#
# ```javascript
# if (5 === "5"){
#     console.log("É verdadeiro!")
# }else{
#     console.log("É falso!")
# }
# // Aqui a resposta é "É falso!"
#
# if (5 == "5"){
#     console.log("É verdadeiro!")
# }else{
#     console.log("É falso!")
# }
# // Aqui da verdadeiro.
# ```
#
# Através do Operador ternário:
#
# ```javascript
# // Modo mais simples de fazer, do que a comparação acima
# 5 === "5" ? console.log("É verdadeiro!") : console.log("É falso!")
# // Falso
#
# 5 == "5" ? console.log("É verdadeiro!") : console.log("É falso!")
# // Verdadeiro
# ```
# Dentro do ItemList.jsx
#
# ```jsx
# {items ===5? (
# <>
#     <SingleItem/>
#     <SingleItem/>
#     <SingleItem/>
#     <SingleItem/>
#     <SingleItem/>
# </>
# ):(
#     <>
#     <SingleItem/>
#     <SingleItem/>
#     <SingleItem/>
#     <SingleItem/>
#     <SingleItem/>
#     </>
# )
#
# console.log("Verdadeiro") : console.log("Falso")
#
# }
#
# ```
#
# Use as ferramentas que a programação lhe possibilita.
#
# No javascript do myArray
#
# ```javascript
# const myEmptyArray = []
# const myArray = [1, 2, 3, 4, 5]
# const obj = {chave, valor, chave2, valor2 }
# const emptyObj = {}
# ```
#
# O Array sempre começa no 0. Ele pega através da posição, e não pelo valor. Ele vai pelo indíce, no exemplo acima, se pedissimos 0 do myArray ele apontaria o 1, por exemplo.
#
# ```javascript
# // Estrutura de repetição
# for (let index = 0; index < bound, index++){
#     console.log(index)
# }
# ```
#
# Uma variável constante não muda, ou seja isso é usando o let. Ele pode mudar a variável por causa do indice = index.
#
# Segunda instrução, quando eu vou parar ela está dentro do index < bound. O index ++ é um incremento, ou seja conforme for fazendo o console.log, ele vai executando, até dar false. Ele só mostraria até o 4, caso colocasse o 5 no lugar no bound por exemplo.
#
# Como acessar o valor do myArray para encontrar o valor 2 por exemplo:
#
# ```javascript
# // Estrutura de repetição
# for (let index = 0; index < bound, index++){
#     console.log(myArray[index])
# }
# ```
#
# Formas mais eficientes de percorrer o myArray.
#
# ```javascript
# myArray3.map(
#     (currentValue, index) => currentValue
# )
# ```
#
# Esse array é melhor para poder continuar trabalhando, enquanto o for não tem essa possibilidade, você teria que construir isso a mão. Ele vai pegar e retornar um array, e para cada elemento ele vai ta fazendo alguma coisa do lado.
#
# Nós usaremos isso para retornar o SingleItem.
#
# Um array com 5 elementos:
#
# ```javascript
# Array(items).fill().map(
#     (currentValue, index) => "SingleItem"
# )
# ```
#
# O fill permite que não fique faltando valores, e ele basicamente intera o código.
#
# Jogaresmo no App2 o "SingleItem" repetido, porque iremos fazer de outra forma no ItemList.jsx
#
# no caso desta forma
#
# ```jsx
# <div className="item-list__container">
#     {Array(items)
#     .fill()
#     .map(() => (
#     <SingleItem key={`${title}}/>
#     ))}
# ```
#
# Prop é um parâmetro que estamos passando para um componente.
#
# ### Template Strings
#
# Elas são usando crase. Emtão elas ficarão dessa forma:
#
# ```javascript
# `${title} - escreverqualquercoisa - ${number + items}`
# ```
#
# Lembrando que **NÃO É** aspas únicas, mas sim crase, o símbolo que fica ao lado do "p". Para que a crase seja funcional, clique em shift+"`" ai sim ela aparecerá da forma correta.
#
# Isso serve para misturar variáveis com escritas.
#
# Comparação: Isso é equivalente as **f strings** em **Python**.
#
# no artists.js temos um array com inúmeros objetos, que ele sempre está entre chaves. Ele não está armazenando números, ou escritas, mas sim objetos, apesar de também ser possível armazenar números e escritas.
#
# Para exportar sem ser default precisa importar entre-chaves, e precisa seguir alguns padrões para poder exportar.
#
# você pode exportar direto na instrução, uma forma mais prática.
#
# Exemplo:
#
# ```javascript
# export const artistArray
# // Dentro do arquivo do artists.js
# ```
#
# como funciona o filter
#
# ```javascript
# myArray3.filter((currentValue, Index)=>  index < 3)
# // Para cada elemento ele avalia se é True or False, se passou pela regra, vai para array, caso contrário ele é tirado fora.
#
# // Faremos isso no vscode
# const items = 5
# ```
#
# O filter serve justamente para filtrar. Isso possibilita resolver o problema relacionado ao número de artistas e músicas aparecendo.
#
# Agora iremos para as variáveis, já que está tudo repetido, com mesmo artista, e informações.
#
# toda vez que estiver interando o currentValue, não precisa deixar o currentValue de cima. Então ficará na verdade desta forma currentObj.
#
# ```jsx
# <SingleItem
#     id={currObj.id}
#     name={currObj.name}
#     image={currObj.image}>
# ```
#
# Essa parte erve para ajustarmos os artistas. E agora precisaremos partir para as músicas agora, para que fique mais eficiente, bem menos linhas de código, bem mais lógico e fácil para ajustes futuros.
#
# uma forma de facilitar mais ainda
#
# ```javascript
# const newObj = obj
# // Quando você faz isso, você não está apenas criando uma cópia, você está também vínculando. Ou seja, isso aqui não é uma boa prática.
#
# const newObj = {...obj}
# // Aqui serve para podermos armazenar da forma correta, para realmente fazermos uma cópia sem vincularmos.
# ```
#
# Essa foi a forma de resolver a primeira parte, da parte de artistas. Agora nos devemos ir de verdade para o ajuste da parte de música, com isso agora iremos ir para os props.
#
# No main.jsx
#
# ```jsx
# <ItemList title="Artistas" >
# ```
#
# Lógica para os valores alocados em const SingleItem.
#
# A forma mais eficiente de fazermos o
#
# ```jsx
# {artist === undefined ? "Artista" : artist}
#
# // Outra forma de fazer isso
# {artist ? "Artista" : artist}
#
# // Forma mais funcional, simples e limpa.
# {artist ?? "Artista"}
# ```
#
# Temos que fazer a ancora para que vá para um link.
#
# colocaremos um caminho no ItemList.
#
# ```jsx
# // Usando o Path
# path
# ```
#
# Isso servirá para passar as informações corretas de link para o "Mostrar tudo" tanto do Artista quanto das Músicas.
#
# ```jsx
# idPath ={idPath}
# ```
#
#
# ### Estruturas de páginas
#
# Teremos 5 páginas nas quais faremos isso, no App.jsx. E baixaremos um novo pacote, e vamos abrir um novo terminal e vamos botar um.
#
# npm i react-router-dom
#
# Depois de instalar esse pacote, faremos alguns imports:
#
# ```jsx
# import { BrowserRouter, Routes, Route} from "react-router-dom";
#
# const App = () => {
#     return(
#         <BrowserRouter>
#         <Header/>
#
#         <Routes>
#         <Route path="/" element={<Home/>} />
#         <Routes/>
#         </BrowserRouter>
#     );
# };
# ```
#
# Adicionaremos mais imports, e mais informações dentro do Routes, mas isso será depois quando estivermos botando em prática.
#
# criaremos um newe folder com nome: pages, e criaremos 2 new files: Home.jsx, Artist.jsx, Artists.jsx, Song.jsx, Songs.jsx.
#
# Na página home:
#
# ```jsx
# import Main from "../components/Main";
#
# const Home = () => {
#     return<Main/>(
#
#     )
# }
# ```
#
# Todas as ancoras, trocaremos pelo link. Para que não atualize sempre a página que ficar trocando de páginas.
#
# Porém fica assim:
#
# ```jsx
# <link to="/">
# </link>
# ```
#
# O que mudou? Ao invés do href da ancora, vamos colocar o "to" no lugar.
#
# ### Minhas Conclusões sobre a aula 2
#
# Aula um pouco mais curta, porém sensacional, entendi algumas bases do Backend, e como usar ao meu favor, é mais difícil por envolver muita lógica, porém é a parte justamente que serve para facilitar vários conceitos. Já que na aula 1 utilizamos de uma linguagem com muito mais informação na tela, de forma mais complexa, e agora podemos enxugar boa parte das informações.
#
# Aprendi mais coisas, reforcei conceitos na minha cabeça, como camelCase e seus usos, aprendi muito sobre Javascript, e como aplicar coisas de javascript dentro de um arquivo JSX, então foi um aprendizado extenso.
#
# Assim como da última vez, colocarei em prática amanhã. E colocarei minhas conclusões após a prática, pode ser que não consiga fazer tudo amanhã, mas seguiremos tentando, hoje conseguimos concluir a aula 1, e espero que aula 2 possa ser concluída com êxito também.
#
# **Obs**: Devido alguns problemas que tive em meu código, tive que refazer do zero as coisas. Então acabou que não conclui a aula 2 da forma que imaginava que iria concluir, mas farei o possível para ter todas informações a mão, e reproduzi-lá da forma correta para poder concluir mais um projeto. Quando eu concluir irei dar minhas ressalvas.
#
# ### Anotações App2.jsx Bônus em Momento de Prática:
#
# ```jsx
# // Forma não eficiente de fazer o código. Mas é uma forma também:
#        /* {items === 5 ? (
#           <>
#             <SingleItem />
#             <SingleItem />
#             <SingleItem />
#             <SingleItem />
#             <SingleItem />
#           </>
#         ) : (
#           <>
#             <SingleItem />
#             <SingleItem />
#             <SingleItem />
#             <SingleItem />
#             <SingleItem />
#             <SingleItem />
#             <SingleItem />
#             <SingleItem />
#             <SingleItem />
#             <SingleItem />
#           </>
#         )} */
# ```
# ### Conclusão após a prática
#
# Teve uns erros mas consegui me virar, até porque foram erros meus kkkkkk. E no final das contas deu para ter um ótimo resultado, aula sensacional, bem simples até, mas a aplicação de novas lógicas e coisas do tipo fizeram a aula render muito, espero que tenha muito acréscimo nas próximas aulas, pois hoje aprendi muito também. Na prática se vê os erros, se entende melhor a lógica por trás, e também traz a prática codar, que é a melhor parte da programação. Apesar do atraso consegui entregar bem o de hoje, o planejamento era fazer a Aula 2 e a 3 de uma vez só, só que só esse já durou um bom tempo, então deixarei a aula 3 para amanhã.
#
# Resultado de hoje:
# <img src="./Resultados em Imagens/ProjetoSpotify-Aula2-Resultado.png">

# %% [markdown]
# # Aula 3 Conexão Front e Back-end
#
# Primeiro iremos mexer com o Artits.jsx
#
# Devemos passar uma informação através de props no Main para que ele específique o caso exato de cada coisa para que apareça as páginas corretas quando colocarmos para abrir as páginas.
#
# Vamos usar uma estrutura if para especificar que é artistas ou músicas que queremos que seja visto após uma ação nossas.
#
# ```jsx
# {type === "artists" || type === undefined ?
#     <ItemList
#     title="Artistas"
#     >}
# ```
#
# Dentro do ItemList.jsx também teremos que importar algo:
#
# ```jsx
#
# import {Link, useLocation}
#
# const {pathname} = useLocation()
# let finalItems;
#
# finalItems = isHome ? Items :Infinity;
#
# const isHome = pathname === "/";
# {isHome ? (
#     <Link to{path} className="item-list__link"> </Link>
# )}
# ```
#
# ### Criação de novas páginas:
#
# Dentro do Artist.jsx
#
# div . artist header com isso ele cria um
#
# ```jsx
# <div className="artist__header"></div>
# sytle={{
#     backgroundImage:"linear-gradient"(to bottom, var...)
# }}
# // Tem mais informações que não adicionei aqui
# ```
# Anotações no App2.jsx
#
# ````jsx
# // kebabcase
# ````
# Criaremos nos componente um Songlist.jsx para adicionar informações de músicas dentrao das músicas quando escolhermos um artista.
#
# E também criaremos um SongItem.jsx
#
# importaremos o SongItem.jsx dentro do Songlist.jsx
#
# ```jsx
# const SongItem = () => {
#     return (
#         <Link to="/song/1" className="song-item">
#     )
# }
# ```
# Teremos também a parte de Song.jsx.
#
# Essa parte servirá justamente para irmos para parte da música, para poder dar play nela.
#
# Aqui pra frente, é uma parte que foi focada em filtrar músicas, artistas e outras questões da página, para que não haja repetições e outros problemas.
#
# Aqui é uma parte de lógica que adicionamos para que rode o código do Artist.jsx:
#
# ```jsx
# const randomIndex = Math.floor(Math.random() * (songArrayFromArtist.lenght - 1))
#
# // Exemplos da aplicação acima, como elas iriam funcionar:
# console.log(Math.floor(Math.random() * 10));
# console.log("Tamanho do Array:" + songArrayFromArtist.lenght)
# ```
#
# ### Parte da Música em si
#
# A tela que tem a música com a foto do album de fundo, o play, ir pra próxima música, música anterior. E outras informações mais.
#
# Um
#
# ```jsx
# // Song.jsx
# console.log(id);
# ```
#
# Permite que nós vejamos qual o número da música em que estamos na tela de música.
#
# Por agora são mais alguns ajustes para que informações de Front-End apareçam, e para parte de Back-end é mais os ajustes de códigos, e formas de organizar os códigos para que as inforamções façam sentido no Front-End.
#
# Foram mais usos repetidos de coisas que já utilizamos, um reforço tanto de front-end, quanto de back-end
#
# Por agora estamos mexendo com mais coisas do SongList.jsx.
#
# App2.jsx
#
# ```jsx
# // Quando componentes se re-renderizão?
# // Uma das ocaiões é quando uma variável de estado usada por esse componente é atualizada.
#
# // Essa parte abaixo é no SongList.jsx
# // Hook = Variável de estado
# const items = useState(5);
# console.log(items)
# // Isso cospe um array e um "f" de função.
#
# // A forma que utilizaremos dentro do nosso projeto
# const [items, seItems] = useState(5);
# ```
#
# Isso serve para mostrar um máximo de informações para depois o "ver mais" mostrar mais informações. Isto na parte do campo do artista, onde mostra uma imagem do artista, e suas músicas. Um máximo até onde vai, e o que  ver mais vai mostrar.
#
# Para finalizar temos que passar informações para nosso link de ir para próxima música ou a anterior. Já tem a lógica de randomIdFromArtist.
#
# A 2 formas de fazermos em ordem de música indo pra frente e para trás em ordem, ou outra forma é ir aleatório nas músicas em si.
#
# Algumas alterações de randomIdFromArtist em algumas pastas .jsx para que as coisas façam sentido, e algumas mudanças de coisas html, para javascript.
#
# ### Conclusões Aula 3
#
# Hoje foi uma aula verdadeiramente focada em Full-Stack, tanto conceitos de Front quanto de Back foram passados, muita lógica e coisas novas passadas.
#
# Eu acabei por não anotar tantas coisas, porque eu estava com uma certa falta de foco, e também porque hoje resolvi dar uma atenção mais visual para a aula em si, porque foram muitos conteúdos passados. Teve muita coisa repetida, mas é claro, para reforçar conceitos, e teve muita coisa nova, mas a parte da coisa nova ta mais voltada mesmo para atualizações de pastas, adição de novas pastas, criação de novas lógicas e coisas do tipo.
#
# Botarei em prática assim que possível, já que tive um atraso da aula 1 pra 2 por uns problemas técnicos que eu tive, mas farei o possível para concluir esse projeto e lança-lo em breve. E também darei minhas consclusões com a prática já envolvida.
#
# ### Conclusões após a prática
#
# Uma aula bem voltada para o front-end mesmo, houve muita lógica de javascript. Mas a ideia era puxar bastante coisa do css que ja estava pronta, então não foi tão difícil, me deparei com alguns erros, mas foram por parte de mim mesmo, questão de escrita e outras coisas mais. Foi uma aula ótima, deu para fazer bastante coisa.
#
# Gostei de ver as coisas funcionando, e agora a próxima aula é apenas a finalização, deixar tudo funcional, utilizar banco de dados, e coisas mais. Acredito que a aula 4 seja a aula que irei gostar mais de por em prática, mas em geral a aula 3 foi ótima também. Aprendi muito novamente. Muita prática voltada a coinceitos já utilizados. E muita lógica. Por incrível que pareça, a parte que mais estou gostando desse curso.

# %% [markdown]
# # Aula 4: Deploy na Réplica do Spotify
#
# ### O que iremos fazer hoje:
#
# - Construir a API
# - Conexão com o Banco de Dados
# - Conectar o Front com o Back
# - Lógicas do Player
# - Github e Deploy
#
# ### Como iremos começar isto
#
# Criaremos essa nossa API. E iremo usar uma nova ferramenta, o express. Primeiramente iremos separar em pastas, o que é do fron-end, e o que é do back-end.
#
# A API será a responsável pela conexão com o banco de dados.
#
# Primeiramente entraremo no back-end, com **cd back-end** no terminal, após criarmos a pasta e adicionarmos o package.json dentro dela.
#
# Após isso, na pasta botaremos **npm i express**.
#
# Criaremos uma pasta nova com nome de api, e um arquivo com nome de server.js dentro desta pasta.
#
# server.js:
#
# ```javascript
# // AP significa Application Programming Interface
# // Tipos de requisições: POST, GET, PUT, DELETE
# // CRUD - Create Read Update Delete
# // Endpoint
# // Middleware
#
# import express from 'express'
# import {artistArray} from "linkaquidolocal.js";
# import {songsArray} from "linkaquidolocal.js";
# import cors from "cors"
# import {db} from "connect.js"
#
# const app = express();
# const PORT = 3001;
#
# app.use(cors());
# // Estamos usando a porta 3001 porque a 3000 já está ocupada pela parte do front-end do projeto.
#
# // app.get("/", (request, response) => {
# //     response.send("Ola, Mundo!");
# // } Teste esse antes de usar os de baixo
#
# app.get("/artists", (request, response) => {
#     response.send(artistArray);
# }
# app.get("/songs", (request, response) => {
#     response.send(songsArray);
# }
#
# )
#
# app.listen(PORT, () =>{
#     console.log(`Servidor está escutando na porta ${PORT}`);
# })
# // Executaremos o arquivo que queremos usar com o comando node../api/server.js
# // Pela url apenas pegaremos com o GET a informação, não é possível usar outros tipos de requisições.
# // Quando fazemos alterações temos que "matar" o servidor e dar node../api/server denovo
# // Outra alternativa é dar node --watch ../api/server.js, isso faz com que se atualize sempre que você abrir o localhost novamente.
#
#
# ```
#
# ### Informações importantes para está aula
#
# -Extensão para navegador, para ele cuspir informações formatadas na web: -JSON Formatter do Chrome
# -Teremos que criar uma conta no Mongodb, se ele te perguntar sobre criar -cluster, nós vamos criar um cluster gratuito.
# -Mongodb é um Banco de Dados não relacional.
# -Se não tiver cluster, iremos em "Create Cluster". Nas opções o último que vai aparecer vai ser o gratuito.
#
# No mongodb, vamos em "Create database" e vamos botar um nome intuitivo. Iremos em "Insert Document". Ele vai gerar um id mais robusto.
#
# Vamos fazer com uma id feita por ele, escolheremos um nome da música, e o artista.
#
# Iremos em Network Access. Isso é quai ips que podem ser acessados. Você tem que adicionar o ip, no caso o nosso.
#
# Vamos em Browse Connect, e iremos em Drivers.
#
# Driver: Node.js
# Version: A mais atual.
#
# Tem que anotar o id.password, se perder você perde a conexão.
#
# connect.js:
#
# ```javascript
# // Javascript Assincrono
# // await async para dizer para esperar para poder sincronizar as informações
# // Fullfilled para prencher as informações
# import{MongoClient} from "mongodb";
#
# const URI = "link aqui"
#
# const client = new MongoClient(URI);
#
# // db é de Database
# export const db = client.db("spotifyProjeto");
# // const songCollection = await db.collection("songs").find({}).toArray();
#
# // const songCollection = db.collection("songs").find({}).toArray();
# // Aqui estamos pegando nosso database em específoco a songs, e o find({}) define que queremos pegar tudo, e o toArray(); para podermos ler isso. Com isso ele vai dar um erro de Promise. Aqui ele tem que esperar algumas coisas acontecer para poder funcionar . Daremos ctrl+c no terminal para quebrar a conexão.
#
# console.log(db);
#
# ```
#
# insertMany.js
#
# ```javascript
# import {artistArray} from "linkaqui.js"
# import {songstArray} from "linkaqui.js"
# import {db} from "connect.js"
#
#
# const newArtistArray = artistArray.map((currentArtistObs)=>{
#     const newArtistObj = {...currentArtistObj};
#     delete newArtistObj.id
#
#     return newArtistObj;
#
# }
# )
# // Tratamento das informações para poder adicionar o id do Mongodb
#
# const newSongsArray = songsArray.map((currentArtistObs)=>{
#     const songsArtistObj = {...currentSongstObj};
#     delete songsArtistObj.id
#
#     return songsArtistObj;
#
# }
# )
#
# const response = await db.collection("songs").insertMany(newSongsArray);
# const response = await db.collection("artists").insertMany(newArtistsArray);
#
# console.log(responseSongs)
# console.log(responseArtists)
# //console.log(newArtistArray);
# //console.log(newSongsArray);
# // console.log(songsArray);
#
# ```
#
# Aqui temos uma API, um Banco de Dados e uma conexão da API com o Banco de Dados.
#
# ### Agora teremos que conectar o front com o back
#
# As informações do Front ainda estão dentro da pasta de front-end que separamos.
#
# Vamos criar uma pasta com nome de api e botarmos um arquivo com nome api.js
#
# api.js:
#
# ```javascript
# // Fetch e Axios
# // Usaremos o axios dando npm i axios
# import axios from "axios";
#
# const URL = "http://localhost:3001";
# // Pra isso funcionar precisamos do Cors que adicionamos no server.js
#
# export const responseArtists = await axios.get(`${URL} + /artists`)
# export const responseSongs = await axios.get(`${URL} + /songs`)
#
#
# // console.log(responseArtists);
# // aqui tem mais informações puxadas do que necessário
#
# //Aqui ele puxa do ponto que queremos mesmo.
# console.log(responseArtists.data);
#
# ```
#
# artists.js
#
# ```javascript
# import {artistArray} from "blablabla"
#
# export{artistArray}
# ```
#
# songs.js
#
# ```javascript
# import {songsArray} from "blablabla"
#
# export{songsArray}
# ```
#
# Para as coisas funcionarem iremos procurar o id nos arquivos, e damos um ctrl+f e filtramos na pesquisa na segunda opção. E escolhemos o que queremos mexer. Iremos ignorar alguns, e iremos tratar de outros.
#
# No db ao invés de estar com apenas id, está com _id, então faremos isso de forma simples vendo quais ids iremos mexer ou alterar de id para _id. Trataremos de alguns problemas que irão rolar nos códigos, e assim que ajustar o front-end funcionará corretamente.
#
# Até aqui já conectamos o Front com o Back.
#
# ### Lógicas do Player
#
# Sairemos das partes de Banco de Dados e Back-End em geral e iremos focar no Player.jsx
#
# Teremos que introduzir um elemento html no player.jsx
#
# Player.jsx
#
# ```jsx
# import {useState} from "blablabla"
# import {useRef, useEffect} from "react"
# import {faCirclePlay} from "fontawesome"
# import {faCirclePause} from "fontawesome"
#
# const splitArray = timeString.split(":")
# const minutes = Number(splitArray[0]);
# const seconds = Number(splitArray[1]);
#
#
# const formatTime = (timeinSeconds) => {
#     const minutes = Math.floor(timeInSeconds / 60).toString().padStart(2,"0");
#     const seconds = Math.floor(timeInSeconds - muntes * 60).toString().padStart(2,"0");
#
#     return `${minutes}:${seconds}`
# }
#
# const audioPlayer = useRef();
# consst progressBar = useRef();
# const [isPlaying, setIsPlaying] = useState(false);
# const [currentTime, setCurrentTime] = useState(fomatTime("0"));
# // console.log(audioPlayer.current.play())
#
# const playPause = () => {
#     isPlaying ? audioPlayer.current.pause(): audioPlayer.current.play();
#     setIsPlaying(!isPlaying);
#
#     console.log(audioPlayer.current.currentTime)
# }
#
# useEffect(()=>{
#     const intevalId = setInterval(() =>{
#         if (isPlaying)
#         setCurrentTime(fomatTime(audioplayer.current.currentTime)):
#     progressBar.current.style.setProperty(
#
#     )
# }, 1000)
# })
#
# // A exclamação inverte o que está fazendo
#
# <audio ref={audioPlayer} src={audio}></audio>
#
# const audioPlayer = document.querySelector("audio")
#
# audioPlayer
#
# // Para tocarmos a música
# audioPlayer.play()
#
# // Para pausarmos a música
# audioPlayer.pause()
#
# // Dentro do botão do FontAwesome no botão colocaremos:
# onClick={() => playPause()}
#
# // Alterações na Player bar__progress.
# ```
#
# Faremos agora uma manipulação do dom. Vamos usar variável de estado para re-renderizar as informações. Colocaremos dentro de condições, de quando for para play e para pause, para mudar icones, para funcionar da forma correta, e vice-versa.
#
# ### Conclusões Aula 4 a última aula:
#
# Uma aula incrível assim como as outras, gostei muito da parte de APIs, back-end e banco de dados, área essa que eu achei que nunca gostaria de verdade, e achei muito boa, juntar o front-end com o back-end é fora do normal. Agora entendo porque as pessoas almejam tanto trabalhar como full-stack. Talvez isso possa ser um motivador para mais algo que eu possa desejar ser bom no futuro. Eu no momento estou focado em Python, mas pretendo aprender muito sobre Javascript em um futuro quem sabe. Até mesmo quem sabe se especializar em full-stack, porém por agora terei que ter mais conclusões, fazer as coisas de forma prática para ver tudo funcionando e poder lançar no Github. Essa é um Jornada que eu tive com a Hashtag, até agora aprendi muito, e pretendo fazer mais jornadas futuramente, se caso você se interessou em minha Jornada, eu ainda farei algumas coisas para finalizar. E bom, ainda não lancei no Github, então realmente aqui vai ficar claro futuramente
#
# ### Conclusão Prática da Última aula
#
# Aqui é um finalmente haha, eu acabei demorando para chegar aqui. Mas valeu muito o esforço, apesar da parte do back-end ter sido extremamente simples, deu pra aprender bastante coisa. Realmente foi divertido integrar um no outro, utilizar novas ferramentas como o Mongodb, essa parte para mim inclusive realmente foi bem mágica haha, já que basicamente tu passa as informações pro mongodb, ele armazena, e depois disso tu não precisa delas mais no seu computador, pois estão armazenadas no banco.
#
# Em geral foi ótimo, minha aula favorita facilmente. Passei algumas dores de cabeça, mas no final das contas consegui me resolver. Inclusive eu acreditava que ia passar dor de cabeça em alguma parte, mas foi muito pelo contrário. Negócio agora é focar em coisas mais, e quando necessário botar esses conhecimentos em prática.
#
# Tudo que aprendi aqui foi muito valioso, inclusive aprendi que javascript, e JSX são linguagens excelentes, e pretendo estudar mais sobre elas. No mais é isso, se você leu minhas conclusões até aqui, agradeço desde já, e espero que tenha gostado também da jornada que foi chegar até aqui. Até uma próxima!!
